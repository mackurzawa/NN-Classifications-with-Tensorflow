# %% [markdown]
# # Clothes Classification

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
from matplotlib import pyplot as plt

# %%
classes_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot']

# %%
len(classes_names)
# Out:
# 10

# %%
plt.figure(figsize=(15, 15))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.imshow(X_train[i], cmap=plt.cm.binary)
  plt.title(classes_names[y_train[i]])
  plt.axis(False)

# %%
# Shape
X_train[0].shape, y_train[0].shape
# Out:
# ((28, 28), ())

# %%
# Input Shape
X_train[0].shape
# Out:
# (28, 28)

# %%
# Normalizing for better results
X_train_norm = X_train / 255.
X_test_norm = X_test / 255.

# %% [markdown]
# ## First model

# %%
tf.random.set_seed(42)

clothes_model_1 = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

clothes_model_1.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                        optimizer='Adam',
                        metrics=['accuracy'])

clothes_history_1 = clothes_model_1.fit(X_train_norm, y_train, epochs=10, validation_data=(X_test_norm, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 2s 846us/step - loss: 0.4995 - accuracy: 0.8234 - val_loss: 0.4157 - val_accuracy: 0.8511
# Epoch 2/10
# 1875/1875 [==============================] - 1s 787us/step - loss: 0.3681 - accuracy: 0.8665 - val_loss: 0.4468 - val_accuracy: 0.8442
# Epoch 3/10
# 1875/1875 [==============================] - 2s 805us/step - loss: 0.3350 - accuracy: 0.8759 - val_loss: 0.3898 - val_accuracy: 0.8579
# Epoch 4/10
# 1875/1875 [==============================] - 1s 768us/step - loss: 0.3117 - accuracy: 0.8855 - val_loss: 0.3912 - val_accuracy: 0.8593
# Epoch 5/10
# 1875/1875 [==============================] - 1s 768us/step - loss: 0.2963 - accuracy: 0.8897 - val_loss: 0.3631 - val_accuracy: 0.8683
# Epoch 6/10
# 1875/1875 [==============================] - 1s 771us/step - loss: 0.2822 - accuracy: 0.8950 - val_loss: 0.3786 - val_accuracy: 0.8569
# Epoch 7/10
# 1875/1875 [==============================] - 1s 792us/step - loss: 0.2734 - accuracy: 0.8974 - val_loss: 0.3610 - val_accuracy: 0.8726
# Epoch 8/10
# 1875/1875 [==============================] - 1s 781us/step - loss: 0.2618 - accuracy: 0.9014 - val_loss: 0.3294 - val_accuracy: 0.8833
# Epoch 9/10
# 1875/1875 [==============================] - 1s 771us/step - loss: 0.2515 - accuracy: 0.9061 - val_loss: 0.3360 - val_accuracy: 0.8836
# Epoch 10/10
# 1875/1875 [==============================] - 2s 811us/step - loss: 0.2448 - accuracy: 0.9076 - val_loss: 0.3361 - val_accuracy: 0.8813

# %%
import pandas as pd

# %%
pd.DataFrame(clothes_history_1.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Finding best learning rate

# %%
tf.random.set_seed(42)

clothes_model_2 = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 0.001 * 10**(epoch/20))

clothes_model_2.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                        optimizer='Adam',
                        metrics=['accuracy'])

clothes_history_2 = clothes_model_2.fit(X_train_norm, y_train, epochs=40, callbacks=[lr_callback], validation_data=(X_test_norm, y_test))
# Out:
# Epoch 1/40
# 1875/1875 [==============================] - 2s 839us/step - loss: 0.4995 - accuracy: 0.8234 - val_loss: 0.4157 - val_accuracy: 0.8511 - lr: 0.0010
# Epoch 2/40
# 1875/1875 [==============================] - 1s 792us/step - loss: 0.3720 - accuracy: 0.8643 - val_loss: 0.4423 - val_accuracy: 0.8489 - lr: 0.0011
# Epoch 3/40
# 1875/1875 [==============================] - 1s 798us/step - loss: 0.3415 - accuracy: 0.8747 - val_loss: 0.3917 - val_accuracy: 0.8591 - lr: 0.0013
# Epoch 4/40
# 1875/1875 [==============================] - 1s 792us/step - loss: 0.3245 - accuracy: 0.8820 - val_loss: 0.4127 - val_accuracy: 0.8537 - lr: 0.0014
# Epoch 5/40
# 1875/1875 [==============================] - 1s 797us/step - loss: 0.3143 - accuracy: 0.8831 - val_loss: 0.3603 - val_accuracy: 0.8702 - lr: 0.0016
# Epoch 6/40
# 1875/1875 [==============================] - 2s 824us/step - loss: 0.3027 - accuracy: 0.8867 - val_loss: 0.3865 - val_accuracy: 0.8544 - lr: 0.0018
# Epoch 7/40
# 1875/1875 [==============================] - 1s 794us/step - loss: 0.2977 - accuracy: 0.8895 - val_loss: 0.3625 - val_accuracy: 0.8751 - lr: 0.0020
# Epoch 8/40
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.2968 - accuracy: 0.8895 - val_loss: 0.3573 - val_accuracy: 0.8758 - lr: 0.0022
# Epoch 9/40
# 1875/1875 [==============================] - 1s 792us/step - loss: 0.2925 - accuracy: 0.8905 - val_loss: 0.3649 - val_accuracy: 0.8749 - lr: 0.0025
# Epoch 10/40
# 1875/1875 [==============================] - 2s 819us/step - loss: 0.2943 - accuracy: 0.8908 - val_loss: 0.3568 - val_accuracy: 0.8703 - lr: 0.0028
# Epoch 11/40
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.2933 - accuracy: 0.8908 - val_loss: 0.3783 - val_accuracy: 0.8651 - lr: 0.0032
# Epoch 12/40
# 1875/1875 [==============================] - 2s 823us/step - loss: 0.2996 - accuracy: 0.8909 - val_loss: 0.3616 - val_accuracy: 0.8745 - lr: 0.0035
# Epoch 13/40
# 1875/1875 [==============================] - 2s 808us/step - loss: 0.3006 - accuracy: 0.8892 - val_loss: 0.4264 - val_accuracy: 0.8569 - lr: 0.0040
# Epoch 14/40
# 1875/1875 [==============================] - 1s 797us/step - loss: 0.3087 - accuracy: 0.8860 - val_loss: 0.3721 - val_accuracy: 0.8734 - lr: 0.0045
# Epoch 15/40
# 1875/1875 [==============================] - 2s 805us/step - loss: 0.3175 - accuracy: 0.8856 - val_loss: 0.4298 - val_accuracy: 0.8513 - lr: 0.0050
# Epoch 16/40
# 1875/1875 [==============================] - 1s 784us/step - loss: 0.3175 - accuracy: 0.8851 - val_loss: 0.4095 - val_accuracy: 0.8630 - lr: 0.0056
# Epoch 17/40
# 1875/1875 [==============================] - 1s 780us/step - loss: 0.3232 - accuracy: 0.8823 - val_loss: 0.4497 - val_accuracy: 0.8533 - lr: 0.0063
# Epoch 18/40
# 1875/1875 [==============================] - 1s 784us/step - loss: 0.3342 - accuracy: 0.8813 - val_loss: 0.3930 - val_accuracy: 0.8687 - lr: 0.0071
# Epoch 19/40
# 1875/1875 [==============================] - 1s 788us/step - loss: 0.3455 - accuracy: 0.8792 - val_loss: 0.4190 - val_accuracy: 0.8609 - lr: 0.0079
# Epoch 20/40
# 1875/1875 [==============================] - 1s 787us/step - loss: 0.3457 - accuracy: 0.8802 - val_loss: 0.4829 - val_accuracy: 0.8613 - lr: 0.0089
# Epoch 21/40
# 1875/1875 [==============================] - 2s 834us/step - loss: 0.3634 - accuracy: 0.8758 - val_loss: 0.3984 - val_accuracy: 0.8635 - lr: 0.0100
# Epoch 22/40
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.3687 - accuracy: 0.8743 - val_loss: 0.4255 - val_accuracy: 0.8577 - lr: 0.0112
# Epoch 23/40
# 1875/1875 [==============================] - 1s 792us/step - loss: 0.4052 - accuracy: 0.8647 - val_loss: 0.4931 - val_accuracy: 0.8391 - lr: 0.0126
# Epoch 24/40
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.4237 - accuracy: 0.8615 - val_loss: 0.4958 - val_accuracy: 0.8485 - lr: 0.0141
# Epoch 25/40
# 1875/1875 [==============================] - 1s 782us/step - loss: 0.4313 - accuracy: 0.8577 - val_loss: 0.6306 - val_accuracy: 0.8234 - lr: 0.0158
# Epoch 26/40
# 1875/1875 [==============================] - 2s 824us/step - loss: 0.4971 - accuracy: 0.8405 - val_loss: 0.4867 - val_accuracy: 0.8374 - lr: 0.0178
# Epoch 27/40
# 1875/1875 [==============================] - 1s 784us/step - loss: 0.4897 - accuracy: 0.8425 - val_loss: 0.5176 - val_accuracy: 0.8418 - lr: 0.0200
# Epoch 28/40
# 1875/1875 [==============================] - 1s 791us/step - loss: 0.5130 - accuracy: 0.8334 - val_loss: 0.6110 - val_accuracy: 0.8079 - lr: 0.0224
# Epoch 29/40
# 1875/1875 [==============================] - 1s 783us/step - loss: 0.6082 - accuracy: 0.8014 - val_loss: 0.5901 - val_accuracy: 0.8082 - lr: 0.0251
# Epoch 30/40
# 1875/1875 [==============================] - 1s 792us/step - loss: 0.5903 - accuracy: 0.8051 - val_loss: 0.5781 - val_accuracy: 0.8057 - lr: 0.0282
# Epoch 31/40
# 1875/1875 [==============================] - 1s 786us/step - loss: 0.7054 - accuracy: 0.7829 - val_loss: 0.7868 - val_accuracy: 0.7512 - lr: 0.0316
# Epoch 32/40
# 1875/1875 [==============================] - 1s 781us/step - loss: 0.7170 - accuracy: 0.7740 - val_loss: 0.7909 - val_accuracy: 0.7542 - lr: 0.0355
# Epoch 33/40
# 1875/1875 [==============================] - 1s 782us/step - loss: 1.1662 - accuracy: 0.5694 - val_loss: 1.1822 - val_accuracy: 0.5329 - lr: 0.0398
# Epoch 34/40
# 1875/1875 [==============================] - 1s 777us/step - loss: 1.3033 - accuracy: 0.4531 - val_loss: 1.2616 - val_accuracy: 0.4409 - lr: 0.0447
# Epoch 35/40
# 1875/1875 [==============================] - 1s 777us/step - loss: 1.4027 - accuracy: 0.3879 - val_loss: 1.4636 - val_accuracy: 0.3138 - lr: 0.0501
# Epoch 36/40
# 1875/1875 [==============================] - 1s 782us/step - loss: 1.5581 - accuracy: 0.3462 - val_loss: 1.6203 - val_accuracy: 0.2622 - lr: 0.0562
# Epoch 37/40
# 1875/1875 [==============================] - 1s 781us/step - loss: 1.7238 - accuracy: 0.2263 - val_loss: 1.7014 - val_accuracy: 0.1996 - lr: 0.0631
# Epoch 38/40
# 1875/1875 [==============================] - 1s 778us/step - loss: 1.7092 - accuracy: 0.2010 - val_loss: 1.7045 - val_accuracy: 0.2085 - lr: 0.0708
# Epoch 39/40
# 1875/1875 [==============================] - 1s 779us/step - loss: 1.7276 - accuracy: 0.2001 - val_loss: 1.7717 - val_accuracy: 0.1920 - lr: 0.0794
# Epoch 40/40
# 1875/1875 [==============================] - 1s 779us/step - loss: 1.8048 - accuracy: 0.1990 - val_loss: 1.7925 - val_accuracy: 0.1994 - lr: 0.0891

# %%
import matplotlib.pyplot as plt

# %%
learning_rates = 0.001 * 10 ** (tf.range(40)/20)
learning_rates
# Out:
# <tf.Tensor: shape=(40,), dtype=float64, numpy=
# array([0.001     , 0.00112202, 0.00125893, 0.00141254, 0.00158489,
#        0.00177828, 0.00199526, 0.00223872, 0.00251189, 0.00281838,
#        0.00316228, 0.00354813, 0.00398107, 0.00446684, 0.00501187,
#        0.00562341, 0.00630957, 0.00707946, 0.00794328, 0.00891251,
#        0.01      , 0.01122018, 0.01258925, 0.01412538, 0.01584893,
#        0.01778279, 0.01995262, 0.02238721, 0.02511886, 0.02818383,
#        0.03162278, 0.03548134, 0.03981072, 0.04466836, 0.05011872,
#        0.05623413, 0.06309573, 0.07079458, 0.07943282, 0.08912509])>

# %%
plt.semilogx(learning_rates, clothes_history_2.history['loss'])
plt.xlabel('Learning Rate')
plt.ylabel('Loss')
plt.title('Finding the best Learning Rate')
# Out:
# Text(0.5, 1.0, 'Finding the best Learning Rate')

# %% [markdown]
# ## Probably the best lr = 0.001, so default for Adam

# %%
tf.random.set_seed(42)

clothes_model_3 = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

clothes_model_3.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                        optimizer='Adam',
                        metrics=['accuracy'])

clothes_history_3 = clothes_model_3.fit(X_train_norm, y_train, epochs=20, validation_data=(X_test_norm, y_test))
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 2s 883us/step - loss: 0.4995 - accuracy: 0.8234 - val_loss: 0.4157 - val_accuracy: 0.8511
# Epoch 2/20
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.3681 - accuracy: 0.8665 - val_loss: 0.4468 - val_accuracy: 0.8442
# Epoch 3/20
# 1875/1875 [==============================] - 1s 781us/step - loss: 0.3350 - accuracy: 0.8759 - val_loss: 0.3898 - val_accuracy: 0.8579
# Epoch 4/20
# 1875/1875 [==============================] - 1s 781us/step - loss: 0.3117 - accuracy: 0.8855 - val_loss: 0.3912 - val_accuracy: 0.8593
# Epoch 5/20
# 1875/1875 [==============================] - 2s 816us/step - loss: 0.2963 - accuracy: 0.8897 - val_loss: 0.3631 - val_accuracy: 0.8683
# Epoch 6/20
# 1875/1875 [==============================] - 2s 813us/step - loss: 0.2822 - accuracy: 0.8950 - val_loss: 0.3786 - val_accuracy: 0.8569
# Epoch 7/20
# 1875/1875 [==============================] - 1s 799us/step - loss: 0.2734 - accuracy: 0.8974 - val_loss: 0.3610 - val_accuracy: 0.8726
# Epoch 8/20
# 1875/1875 [==============================] - 1s 793us/step - loss: 0.2618 - accuracy: 0.9014 - val_loss: 0.3294 - val_accuracy: 0.8833
# Epoch 9/20
# 1875/1875 [==============================] - 1s 788us/step - loss: 0.2515 - accuracy: 0.9061 - val_loss: 0.3360 - val_accuracy: 0.8836
# Epoch 10/20
# 1875/1875 [==============================] - 1s 787us/step - loss: 0.2448 - accuracy: 0.9076 - val_loss: 0.3361 - val_accuracy: 0.8813
# Epoch 11/20
# 1875/1875 [==============================] - 1s 788us/step - loss: 0.2355 - accuracy: 0.9110 - val_loss: 0.3385 - val_accuracy: 0.8814
# Epoch 12/20
# 1875/1875 [==============================] - 1s 789us/step - loss: 0.2307 - accuracy: 0.9128 - val_loss: 0.3472 - val_accuracy: 0.8824
# Epoch 13/20
# 1875/1875 [==============================] - 1s 794us/step - loss: 0.2218 - accuracy: 0.9164 - val_loss: 0.3396 - val_accuracy: 0.8849
# Epoch 14/20
# 1875/1875 [==============================] - 1s 771us/step - loss: 0.2166 - accuracy: 0.9186 - val_loss: 0.3405 - val_accuracy: 0.8888
# Epoch 15/20
# 1875/1875 [==============================] - 2s 801us/step - loss: 0.2106 - accuracy: 0.9204 - val_loss: 0.3645 - val_accuracy: 0.8761
# Epoch 16/20
# 1875/1875 [==============================] - 2s 848us/step - loss: 0.2036 - accuracy: 0.9228 - val_loss: 0.3520 - val_accuracy: 0.8847
# Epoch 17/20
# 1875/1875 [==============================] - 2s 814us/step - loss: 0.1978 - accuracy: 0.9251 - val_loss: 0.3556 - val_accuracy: 0.8846
# Epoch 18/20
# 1875/1875 [==============================] - 1s 789us/step - loss: 0.1955 - accuracy: 0.9257 - val_loss: 0.3496 - val_accuracy: 0.8893
# Epoch 19/20
# 1875/1875 [==============================] - 1s 791us/step - loss: 0.1927 - accuracy: 0.9270 - val_loss: 0.3606 - val_accuracy: 0.8803
# Epoch 20/20
# 1875/1875 [==============================] - 1s 769us/step - loss: 0.1845 - accuracy: 0.9302 - val_loss: 0.3746 - val_accuracy: 0.8841

# %% [markdown]
# # Evaluating

# %%
from seaborn import heatmap
from sklearn.metrics import confusion_matrix

# %%
from tensorflow.python.ops.gen_math_ops import arg_max
y_pred = clothes_model_3.predict(X_test_norm)
y_pred = tf.argmax(y_pred, axis=-1)
y_pred
# Out:
# <tf.Tensor: shape=(10000,), dtype=int64, numpy=array([9, 2, 1, ..., 8, 1, 5], dtype=int64)>

# %%
Conf_M = confusion_matrix(y_test, y_pred)
Conf_M
# Out:
# array([[868,   2,  10,  13,   5,   1,  95,   0,   6,   0],
#        [  2, 979,   0,  11,   5,   0,   1,   0,   2,   0],
#        [ 22,   1, 793,   8, 120,   0,  55,   0,   1,   0],
#        [ 33,   9,  12, 858,  54,   0,  29,   0,   5,   0],
#        [  1,   1,  74,  18, 878,   0,  27,   0,   1,   0],
#        [  0,   0,   0,   1,   0, 960,   0,  23,   1,  15],
#        [139,   0,  82,  13, 131,   0, 623,   0,  12,   0],
#        [  0,   0,   0,   0,   0,  17,   0, 968,   1,  14],
#        [  5,   0,   5,   1,   6,   3,   4,   2, 974,   0],
#        [  0,   0,   0,   0,   0,  11,   1,  48,   0, 940]], dtype=int64)

# %%
plt.figure(figsize=(10, 7))
heatmap(Conf_M, annot=True, fmt='d');

# %%
import random

# %%
def plot_random_image(model, images, true_labels, classes):
  i = random.randint(0, len(images))

  target_image = images[i]
  pred_probs = model.predict(target_image.reshape(1, 28, 28))
  pred_label = classes[pred_probs.argmax()]
  true_label = classes[true_labels[i]]

  plt.imshow(target_image, cmap=plt.cm.binary)
  plt.title(f'True label: {true_label}\nPredicted label: {pred_label}({pred_probs.max()*100:.2f}%)', c='g' if pred_label == true_label else 'r')
  plt.axis(False)

plot_random_image(clothes_model_3, X_test_norm, y_test, classes_names)

# %% [markdown]
# # Checking Patterns which model recognised

# %%
clothes_model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 100)               78500
#
#  dense_7 (Dense)             (None, 50)                5050
#
#  dense_8 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 84,060
# Trainable params: 84,060
# Non-trainable params: 0
# _________________________________________________________________

# %%
clothes_model_3.layers
# Out:
# [<keras.layers.core.flatten.Flatten at 0x14355033d30>,
#  <keras.layers.core.dense.Dense at 0x14356e7e8b0>,
#  <keras.layers.core.dense.Dense at 0x143550943d0>,
#  <keras.layers.core.dense.Dense at 0x14355094bb0>]

# %%
clothes_model_3.layers[2].get_weights()
# Out:
# [array([[ 0.22977683, -0.02484239,  0.5830752 , ...,  0.0991788 ,
#          -0.10096854,  0.24411313],
#         [ 0.43186218, -0.40977728,  0.22636467, ...,  0.18193685,
#          -0.51998806,  0.42884624],
#         [-0.06618292, -0.38399383, -0.19764125, ...,  0.13162939,
#          -0.06150413, -0.31956974],
#         ...,
#         [ 0.01805598,  0.43206206,  0.32021585, ..., -0.20329513,
#           0.06390385, -0.02112961],
#         [-0.18426238, -0.01402015, -0.13410875, ..., -0.05942649,
#          -0.0617407 ,  0.08460924],
#         [ 0.2555055 ,  0.12824099,  0.00637944, ...,  0.7352479 ,
#           0.13216855, -0.23124716]], dtype=float32),
#  array([ 0.03905263,  0.23006098,  0.5063272 , -0.09252208,  0.29106444,
#         -0.04364362,  0.097878  ,  0.15558693,  0.12412972,  0.04231256,
#          0.22913432,  0.21998678,  0.23498969,  0.38951465,  0.13058278,
#          0.04413498, -0.08809493,  0.42138466,  0.6165969 , -0.17386131,
#          0.4140234 ,  0.72154015,  0.2104545 ,  0.42537627,  0.1725092 ,
#          0.1936829 , -0.18993905,  0.19597237,  0.3967273 ,  0.3163737 ,
#          0.361379  ,  0.34960496,  0.49387202,  0.16434486,  0.3470205 ,
#          0.22374938,  0.05240499,  0.22971144,  0.00681653,  0.15986954,
#          0.45881742,  0.67658126, -0.42334947,  0.20947684,  0.6798458 ,
#          0.00659962,  0.39405972,  0.35974082,  0.48316044,  0.1550261 ],
#        dtype=float32)]

# %%
tf.keras.utils.plot_model(clothes_model_3, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ### (Avaialble on Google Colab)
